# %% [markdown]
# # Demo Pandas

# %%
import pandas as pd 
import numpy as np

# %%
s1 = pd.Series([1,2,3,4])
print(s1)
print(type(s1))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
s2 = pd.Series({'apple':1,'mango':20,'grapes':78})
print(s2)
# Out:
# apple      1
# mango     20
# grapes    78
# dtype: int64

# %%
d1 = pd.DataFrame({"fruits":['grapes','mango','apple','papaya'],
                   "stock": [20,40,78,None]})
print(d1)
# Out:
#    fruits  stock
# 0  grapes   20.0
# 1   mango   40.0
# 2   apple   78.0
# 3  papaya    NaN

# %%
d1.dtypes
# Out:
# fruits    object
# stock      int64
# dtype: object

# %%
df = pd.read_csv(r'C:\Users\VishwasKSingh\Workspace\temp\my_app\data\events.csv')

# %%
df.head()
# Out:
#   event_id                        topic       city  venue_capacity  \
# 0     E001                   Python OOP  Bengaluru              50
# 1     E002               Data Wrangling  Bengaluru              30
# 2     E003                   Python OOP  Bengaluru              40
# 3     E004                   Python OOP     Mysuru              60
# 4     E005  Machine Learning Essentials  Bengaluru              40
#
#   scheduled_date_time instructor_id
# 0    2026-01-13 10:00          I001
# 1    2026-01-16 14:00          I001
# 2    2026-01-19 10:00          I003
# 3    2026-01-22 10:00          I002
# 4    2026-01-25 14:00          I002

# %%
df.head(2)
# Out:
#   event_id           topic       city  venue_capacity scheduled_date_time  \
# 0     E001      Python OOP  Bengaluru              50    2026-01-13 10:00
# 1     E002  Data Wrangling  Bengaluru              30    2026-01-16 14:00
#
#   instructor_id
# 0          I001
# 1          I001

# %%
df.tail()
# Out:
#    event_id                        topic       city  venue_capacity  \
# 7      E008  Machine Learning Essentials  Bengaluru              60
# 8      E009                   Python OOP  Hyderabad              50
# 9      E010                   Python OOP  Bengaluru              40
# 10     E011               Data Wrangling  Bengaluru              60
# 11     E012  Machine Learning Essentials     Mysuru              50
#
#    scheduled_date_time instructor_id
# 7     2026-02-03 09:00          I002
# 8     2026-02-06 10:00          I003
# 9     2026-02-09 11:00          I001
# 10    2026-02-12 11:00          I002
# 11    2026-02-15 11:00          I001

# %%
df['event_id']
# Out:
# 0     E001
# 1     E002
# 2     E003
# 3     E004
# 4     E005
# 5     E006
# 6     E007
# 7     E008
# 8     E009
# 9     E010
# 10    E011
# 11    E012
# Name: event_id, dtype: object

# %%
df.loc[0,'event_id']
# Out:
# 'E001'

# %%
df.iloc[0,0]
# Out:
# 'E001'

# %%
df.describe()
# Out:
#        venue_capacity
# count       12.000000
# mean        45.833333
# std         10.836247
# min         30.000000
# 25%         40.000000
# 50%         45.000000
# 75%         52.500000
# max         60.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             12 non-null     object
#  1   topic                12 non-null     object
#  2   city                 12 non-null     object
#  3   venue_capacity       12 non-null     int64
#  4   scheduled_date_time  12 non-null     object
#  5   instructor_id        12 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 708.0+ bytes

# %%
d1.head()
# Out:
#    fruits  stock
# 0  grapes   20.0
# 1   mango   40.0
# 2   apple   78.0
# 3  papaya    NaN

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fruits  4 non-null      object
#  1   stock   3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes

# %%
d1['stock'].isna().sum()
# Out:
# np.int64(1)

# %%
df[(df['venue_capacity'] == 50) & (df['city'] == 'Bengaluru')]
# Out:
#   event_id       topic       city  venue_capacity scheduled_date_time  \
# 0     E001  Python OOP  Bengaluru              50    2026-01-13 10:00
#
#   instructor_id
# 0          I001

# %%
df.query("venue_capacity == 50 and city == 'Bengaluru'")
# Out:
#   event_id       topic       city  venue_capacity scheduled_date_time  \
# 0     E001  Python OOP  Bengaluru              50    2026-01-13 10:00
#
#   instructor_id
# 0          I001

# %%
import sqlite3
from sqlalchemy.orm import base
from sqlalchemy import create_engine

engine = create_engine("sqlite:///myfile.db")

with engine.connect() as conn:
    df.to_sql(name="events",con=conn,if_exists='replace')

# %%
with engine.connect() as conn:
    df1 = pd.read_sql('SELECT * FROM events', con=conn)

df1.head()
# Out:
#    index event_id                        topic       city  venue_capacity  \
# 0      0     E001                   Python OOP  Bengaluru              50
# 1      1     E002               Data Wrangling  Bengaluru              30
# 2      2     E003                   Python OOP  Bengaluru              40
# 3      3     E004                   Python OOP     Mysuru              60
# 4      4     E005  Machine Learning Essentials  Bengaluru              40
#
#   scheduled_date_time instructor_id
# 0    2026-01-13 10:00          I001
# 1    2026-01-16 14:00          I001
# 2    2026-01-19 10:00          I003
# 3    2026-01-22 10:00          I002
# 4    2026-01-25 14:00          I002
